# %% [markdown]
# ## DAY 2 :

# %% [markdown]
# # DATA ANALYSIS FOR WORLD HAPPINESS REPORT

# %% [markdown]
# - This is an analysis project to understand the world happiness report of countries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - pandas for data manipulation
#
# - matplotlib and seaborn for visualization

# %% [markdown]
# ## Loading Data

# %%
df=pd.read_csv("world-happiness-report - world-happiness-report.csv")
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# ## Inspecting Data

# %%
df.head(5)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df.tail(5)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1944                              54.4                         0.733
# 1945                              55.0                         0.753
# 1946                              55.6                         0.763
# 1947                              56.2                         0.632
# 1948                              56.8                         0.643
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df.sample(5)
# Out:
#         Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1096      Mauritania  2015        3.923               8.542           0.875
# 441   Czech Republic  2012        6.334              10.426           0.912
# 1757          Turkey  2010        5.490               9.906           0.795
# 1084           Malta  2017        6.676              10.635           0.937
# 995            Libya  2012        5.754               9.842           0.855
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1096                             56.10                         0.447
# 441                              68.38                         0.740
# 1757                             64.40                         0.515
# 1084                             72.20                         0.924
# 995                              62.66                         0.712
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# ...

# %% [markdown]
# ## Checking Data Types

# %%
df.dtypes
# Out:
# Country name                            str
# year                                  int64
# Life Ladder                         float64
# Log GDP per capita                  float64
# Social support                      float64
# Healthy life expectancy at birth    float64
# Freedom to make life choices        float64
# Generosity                          float64
# Perceptions of corruption           float64
# Positive affect                     float64
# Negative affect                     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='str')

# %%
df.shape
# Out:
# (1949, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   str
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(9), int64(1), str(1)
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   36
# Social support                       13
# Healthy life expectancy at birth     55
# Freedom to make life choices         32
# Generosity                           89
# Perceptions of corruption           110
# Positive affect                      22
# Negative affect                      16
# dtype: int64

# %% [markdown]
# ## Dataset Overview

# %% [markdown]
# - number of rows = 1949
# - number of columns = 11
# - data types: float = 9,integer = 1,object = 1
# - missing values = none
# - memory used = 167.6 + KB

# %% [markdown]
# ## DAY 3 :

# %% [markdown]
# ##  Data Cleaning

# %% [markdown]
# ### cleaning numeric columns with characters

# %%
df[df["Log GDP per capita"].isnull()]
# Out:
#                    Country name  year  Life Ladder  Log GDP per capita  \
# 423                        Cuba  2006        5.418                 NaN
# 436                      Cyprus  2020        6.260                 NaN
# 709   Hong Kong S.A.R. of China  2020        5.295                 NaN
# 771                        Iran  2018        4.278                 NaN
# 772                        Iran  2019        5.006                 NaN
# 773                        Iran  2020        4.865                 NaN
# 918                      Kosovo  2020        6.294                 NaN
# 1087                      Malta  2020        6.157                 NaN
# 1280               North Cyprus  2012        5.463                 NaN
# 1281               North Cyprus  2013        5.567                 NaN
# 1282               North Cyprus  2014        5.786                 NaN
# 1283               North Cyprus  2015        5.843                 NaN
# ...

# %%
df[df["Country name"]=="Cuba"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 423         Cuba  2006        5.418                 NaN            0.97
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 423                             68.44                         0.281
#
#      Generosity  Perceptions of corruption  Positive affect  Negative affect
# 423         NaN                        NaN            0.647            0.277

# %%
df[df["Country name"]=="Somaliland region"]
# Out:
#            Country name  year  Life Ladder  Log GDP per capita  \
# 1562  Somaliland region  2009        4.991                 NaN
# 1563  Somaliland region  2010        4.657                 NaN
# 1564  Somaliland region  2011        4.931                 NaN
# 1565  Somaliland region  2012        5.057                 NaN
#
#       Social support  Healthy life expectancy at birth  \
# 1562           0.880                               NaN
# 1563           0.829                               NaN
# 1564           0.788                               NaN
# 1565           0.786                               NaN
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 1562                         0.746         NaN                      0.513
# 1563                         0.820         NaN                      0.471
# 1564                         0.858         NaN                      0.357
# ...

# %%
df[df["Country name"]=="Cyprus"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 424       Cyprus  2006        6.238              10.566           0.878
# 425       Cyprus  2009        6.833              10.558           0.812
# 426       Cyprus  2010        6.387              10.551           0.822
# 427       Cyprus  2011        6.690              10.530           0.844
# 428       Cyprus  2012        6.181              10.479           0.767
# 429       Cyprus  2013        5.439              10.414           0.744
# 430       Cyprus  2014        5.627              10.406           0.770
# 431       Cyprus  2015        5.439              10.445           0.770
# 432       Cyprus  2016        5.795              10.506           0.786
# 433       Cyprus  2017        6.062              10.539           0.819
# 434       Cyprus  2018        6.276              10.567           0.826
# 435       Cyprus  2019        6.137              10.585           0.776
# ...

# %%
df=df.dropna(subset=["Log GDP per capita"])

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                    0
# Social support                       13
# Healthy life expectancy at birth     37
# Freedom to make life choices         32
# Generosity                           53
# Perceptions of corruption           109
# Positive affect                      22
# Negative affect                      16
# dtype: int64

# %% [markdown]
# ## DAY 4:

# %%
df[df["Social support"].isnull()]
# Out:
#               Country name  year  Life Ladder  Log GDP per capita  \
# 25                 Algeria  2010        5.464               9.287
# 112                Bahrain  2014        6.165              10.783
# 294                 Canada  2007        7.482              10.739
# 466               Djibouti  2010        5.006               7.812
# 925                 Kuwait  2014        6.180              10.945
# 1164               Morocco  2010        4.383               8.746
# 1310                  Oman  2011        6.853              10.382
# 1423                 Qatar  2010        6.850              11.520
# 1426                 Qatar  2015        6.375              11.486
# 1741               Tunisia  2009        5.025               9.197
# 1814  United Arab Emirates  2014        6.540              11.041
# 1837         United States  2007        7.513              10.933
# 1905               Vietnam  2017        5.175               8.876
#
# ...

# %%
df=df.dropna(subset=['Social support'])

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                    0
# Social support                        0
# Healthy life expectancy at birth     37
# Freedom to make life choices         26
# Generosity                           48
# Perceptions of corruption           102
# Positive affect                      11
# Negative affect                       6
# dtype: int64

# %%
df[df["Healthy life expectancy at birth"].isnull()]
# Out:
#                    Country name  year  Life Ladder  Log GDP per capita  \
# 699   Hong Kong S.A.R. of China  2006        5.511              10.746
# 700   Hong Kong S.A.R. of China  2008        5.137              10.816
# 701   Hong Kong S.A.R. of China  2009        5.397              10.788
# 702   Hong Kong S.A.R. of China  2010        5.643              10.847
# 703   Hong Kong S.A.R. of China  2011        5.474              10.887
# 704   Hong Kong S.A.R. of China  2012        5.484              10.893
# 705   Hong Kong S.A.R. of China  2014        5.458              10.940
# 706   Hong Kong S.A.R. of China  2016        5.498              10.970
# 707   Hong Kong S.A.R. of China  2017        5.362              11.000
# 708   Hong Kong S.A.R. of China  2019        5.659              11.000
# 905                      Kosovo  2007        5.104               8.928
# 906                      Kosovo  2008        5.522               8.981
# ...

# %%
df[df["Country name"]=="Hong Kong S.A.R. of China"]
# Out:
#                   Country name  year  Life Ladder  Log GDP per capita  \
# 699  Hong Kong S.A.R. of China  2006        5.511              10.746
# 700  Hong Kong S.A.R. of China  2008        5.137              10.816
# 701  Hong Kong S.A.R. of China  2009        5.397              10.788
# 702  Hong Kong S.A.R. of China  2010        5.643              10.847
# 703  Hong Kong S.A.R. of China  2011        5.474              10.887
# 704  Hong Kong S.A.R. of China  2012        5.484              10.893
# 705  Hong Kong S.A.R. of China  2014        5.458              10.940
# 706  Hong Kong S.A.R. of China  2016        5.498              10.970
# 707  Hong Kong S.A.R. of China  2017        5.362              11.000
# 708  Hong Kong S.A.R. of China  2019        5.659              11.000
#
#      Social support  Healthy life expectancy at birth  \
# 699           0.812                               NaN
# 700           0.840                               NaN
# ...

# %%
df=df[~((df['Country name']=="Hong Kong S.A.R. of China") & (df['Healthy life expectancy at birth'].isna()))]

# %%
df[df["Country name"]=="Kosovo"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 905       Kosovo  2007        5.104               8.928           0.848
# 906       Kosovo  2008        5.522               8.981           0.884
# 907       Kosovo  2009        5.891               9.008           0.830
# 908       Kosovo  2010        5.177               9.033           0.708
# 909       Kosovo  2011        4.860               9.067           0.759
# 910       Kosovo  2012        5.640               9.086           0.757
# 911       Kosovo  2013        6.126               9.113           0.721
# 912       Kosovo  2014        5.000               9.129           0.706
# 913       Kosovo  2015        5.077               9.182           0.805
# 914       Kosovo  2016        5.759               9.228           0.824
# 915       Kosovo  2017        6.149               9.262           0.792
# 916       Kosovo  2018        6.392               9.296           0.822
# ...

# %%
df=df[~((df['Country name']=="Kosovo") & (df['Healthy life expectancy at birth'].isna()))]

# %%
df[df["Country name"]=="Palestinian Territories"]
# Out:
#                  Country name  year  Life Ladder  Log GDP per capita  \
# 1325  Palestinian Territories  2006        4.716               8.213
# 1326  Palestinian Territories  2007        4.151               8.218
# 1327  Palestinian Territories  2008        4.386               8.276
# 1328  Palestinian Territories  2009        4.470               8.329
# 1329  Palestinian Territories  2010        4.703               8.383
# 1330  Palestinian Territories  2011        4.751               8.474
# 1331  Palestinian Territories  2012        4.647               8.531
# 1332  Palestinian Territories  2013        4.844               8.489
# 1333  Palestinian Territories  2014        4.722               8.457
# 1334  Palestinian Territories  2015        4.695               8.480
# 1335  Palestinian Territories  2016        4.907               8.498
# 1336  Palestinian Territories  2017        4.628               8.485
#
#       Social support  Healthy life expectancy at birth  \
# ...

# %%
df[df["Country name"]=="Palestinian Territories"]["Healthy life expectancy at birth"].mean()
# Out:
# np.float64(62.014799999999994)

# %%
df.loc[(df["Country name"]=="Palestinian Territories") & (df["Healthy life expectancy at birth"].isna()),"Healthy life expectancy at birth"]=(62.014799999999994)

# %%
df[df["Country name"]=="Taiwan Province of China"]
# Out:
#                   Country name  year  Life Ladder  Log GDP per capita  \
# 1669  Taiwan Province of China  2006        6.189              10.613
# 1670  Taiwan Province of China  2008        5.548              10.606
# 1671  Taiwan Province of China  2010        6.229              10.691
# 1672  Taiwan Province of China  2011        6.309              10.705
# 1673  Taiwan Province of China  2012        6.126              10.716
# 1674  Taiwan Province of China  2013        6.340              10.750
# 1675  Taiwan Province of China  2014        6.363              10.798
# 1676  Taiwan Province of China  2015        6.450              10.842
# 1677  Taiwan Province of China  2016        6.513              10.855
# 1678  Taiwan Province of China  2017        6.359              10.871
#
#       Social support  Healthy life expectancy at birth  \
# 1669           0.882                             68.68
# 1670           0.830                             69.14
# ...

# %%
df[df["Country name"]=="Taiwan Province of China"]["Healthy life expectancy at birth"].mean()
# Out:
# np.float64(69.14)

# %%
df.loc[(df["Country name"]=="Taiwan Province of China") & (df["Healthy life expectancy at birth"].isna()),"Healthy life expectancy at birth"]=(69.14)

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                    0
# Social support                        0
# Healthy life expectancy at birth      0
# Freedom to make life choices         25
# Generosity                           48
# Perceptions of corruption           102
# Positive affect                      10
# Negative affect                       6
# dtype: int64

# %% [markdown]
# ## DAY 5 :

# %%
df[df["Negative affect"].isnull()]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 872        Jordan  2018        4.639               9.196           0.800
# 873        Jordan  2019        4.453               9.201           0.793
# 874        Jordan  2020        4.094               9.150           0.709
# 1062     Maldives  2018        5.198               9.826           0.913
# 1380  Philippines  2006        4.670               8.562           0.795
# 1753       Turkey  2005        4.719               9.809           0.820
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 872                               66.8                         0.762
# 873                               67.0                         0.726
# 874                               67.2                         0.779
# 1062                              70.6                         0.855
# 1380                              59.8                         0.828
# ...

# %%
df[df["Country name"]=="Jordan"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 860       Jordan  2005        6.295               9.246           0.920
# 861       Jordan  2007        5.598               9.321           0.841
# 862       Jordan  2008        4.930               9.343           0.766
# 863       Jordan  2009        6.000               9.347           0.899
# 864       Jordan  2010        5.570               9.317           0.918
# 865       Jordan  2011        5.539               9.289           0.878
# 866       Jordan  2012        5.132               9.261           0.829
# 867       Jordan  2013        5.172               9.237           0.840
# 868       Jordan  2014        5.333               9.222           0.816
# 869       Jordan  2015        5.405               9.207           0.830
# 870       Jordan  2016        5.271               9.197           0.820
# 871       Jordan  2017        4.808               9.194           0.815
# ...

# %%
df[df["Country name"]=="Maldives"]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1062     Maldives  2018        5.198               9.826           0.913
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1062                              70.6                         0.855
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 1062       0.024                        NaN              NaN              NaN

# %%
df[df["Country name"]=="Philippines"]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1380  Philippines  2006        4.670               8.562           0.795
# 1381  Philippines  2007        5.074               8.608           0.801
# 1382  Philippines  2008        4.589               8.634           0.798
# 1383  Philippines  2009        4.880               8.632           0.775
# 1384  Philippines  2010        4.942               8.686           0.805
# 1385  Philippines  2011        4.994               8.707           0.789
# 1386  Philippines  2012        5.002               8.756           0.813
# 1387  Philippines  2013        4.977               8.805           0.846
# 1388  Philippines  2014        5.313               8.850           0.813
# 1389  Philippines  2015        5.547               8.896           0.854
# 1390  Philippines  2016        5.431               8.950           0.821
# 1391  Philippines  2017        5.594               9.002           0.851
# ...

# %%
df[df["Country name"]=="Turkey"]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1753       Turkey  2005        4.719               9.809           0.820
# 1754       Turkey  2007        5.623               9.903           0.792
# 1755       Turkey  2008        5.118               9.899           0.645
# 1756       Turkey  2009        5.213               9.838           0.755
# 1757       Turkey  2010        5.490               9.906           0.795
# 1758       Turkey  2011        5.272               9.996           0.692
# 1759       Turkey  2012        5.309              10.026           0.739
# 1760       Turkey  2013        4.888              10.091           0.795
# 1761       Turkey  2014        5.580              10.124           0.863
# 1762       Turkey  2015        5.514              10.166           0.851
# 1763       Turkey  2016        5.326              10.181           0.880
# 1764       Turkey  2017        5.607              10.238           0.876
# ...

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                    0
# Social support                        0
# Healthy life expectancy at birth      0
# Freedom to make life choices         25
# Generosity                           48
# Perceptions of corruption           102
# Positive affect                      10
# Negative affect                       6
# dtype: int64

# %%
df["Negative affect"]=df["Negative affect"].fillna(df.groupby("Country name")["Negative affect"].transform("mean"))

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                    0
# Social support                        0
# Healthy life expectancy at birth      0
# Freedom to make life choices         25
# Generosity                           48
# Perceptions of corruption           102
# Positive affect                      10
# Negative affect                       1
# dtype: int64

# %%
df[df["Positive affect"].isnull()]
# Out:
#               Country name  year  Life Ladder  Log GDP per capita  \
# 126             Bangladesh  2014        4.636               8.164
# 135                Belarus  2008        5.463               9.677
# 264               Cambodia  2007        4.156               7.829
# 779                   Iraq  2013        4.725               9.280
# 872                 Jordan  2018        4.639               9.196
# 873                 Jordan  2019        4.453               9.201
# 874                 Jordan  2020        4.094               9.150
# 1062              Maldives  2018        5.198               9.826
# 1311              Pakistan  2005        5.225               8.218
# 1813  United Arab Emirates  2013        6.621              11.001
#
#       Social support  Healthy life expectancy at birth  \
# 126            0.577                             62.38
# 135            0.904                             61.70
# 264            0.675                             56.10
# ...

# %%
df[df["Country name"]=="Bangladesh"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 118   Bangladesh  2006        4.319               7.783           0.672
# 119   Bangladesh  2007        4.607               7.839           0.514
# 120   Bangladesh  2008        5.052               7.886           0.467
# 121   Bangladesh  2009        5.083               7.924           0.528
# 122   Bangladesh  2010        4.858               7.967           0.549
# 123   Bangladesh  2011        4.986               8.018           0.606
# 124   Bangladesh  2012        4.724               8.070           0.582
# 125   Bangladesh  2013        4.660               8.116           0.530
# 126   Bangladesh  2014        4.636               8.164           0.577
# 127   Bangladesh  2015        4.633               8.216           0.601
# 128   Bangladesh  2016        4.556               8.274           0.649
# 129   Bangladesh  2017        4.310               8.334           0.713
# ...

# %%
df[df["Country name"]=="Belarus"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 133      Belarus  2006        5.658               9.489           0.918
# 134      Belarus  2007        5.617               9.576           0.858
# 135      Belarus  2008        5.463               9.677           0.904
# 136      Belarus  2009        5.564               9.681           0.908
# 137      Belarus  2010        5.526               9.758           0.918
# 138      Belarus  2011        5.225               9.812           0.910
# 139      Belarus  2012        5.749               9.830           0.902
# 140      Belarus  2013        5.876               9.839           0.923
# 141      Belarus  2014        5.812               9.856           0.880
# 142      Belarus  2015        5.719               9.815           0.924
# 143      Belarus  2016        5.178               9.788           0.927
# 144      Belarus  2017        5.553               9.814           0.900
# ...

# %%
df[df["Country name"]=="Cambodia"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 263     Cambodia  2006        3.569               7.746           0.793
# 264     Cambodia  2007        4.156               7.829           0.675
# 265     Cambodia  2008        4.462               7.879           0.619
# 266     Cambodia  2009        4.111               7.865           0.818
# 267     Cambodia  2010        4.141               7.907           0.697
# 268     Cambodia  2011        4.161               7.960           0.716
# 269     Cambodia  2012        3.899               8.014           0.606
# 270     Cambodia  2013        3.674               8.068           0.651
# 271     Cambodia  2014        3.883               8.121           0.693
# 272     Cambodia  2015        4.162               8.173           0.729
# 273     Cambodia  2016        4.461               8.225           0.746
# 274     Cambodia  2017        4.586               8.276           0.765
# ...

# %%
df["Positive affect"]=df["Positive affect"].fillna(df.groupby("Country name")["Positive affect"].transform("mean"))

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                    0
# Social support                        0
# Healthy life expectancy at birth      0
# Freedom to make life choices         25
# Generosity                           48
# Perceptions of corruption           102
# Positive affect                       1
# Negative affect                       1
# dtype: int64

# %%
df[df["Positive affect"].isnull()]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1062     Maldives  2018        5.198               9.826           0.913
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1062                              70.6                         0.855
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 1062       0.024                        NaN              NaN              NaN

# %%
df=df.dropna(subset=["Positive affect"])

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                    0
# Social support                        0
# Healthy life expectancy at birth      0
# Freedom to make life choices         25
# Generosity                           48
# Perceptions of corruption           101
# Positive affect                       0
# Negative affect                       0
# dtype: int64

# %%
df[df["Freedom to make life choices"].isnull()]
# Out:
#       Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 28         Algeria  2014        6.355               9.335           0.818
# 29         Algeria  2016        5.341               9.362           0.749
# 263       Cambodia  2006        3.569               7.746           0.793
# 342          China  2006        4.560               8.696           0.747
# 343          China  2007        4.863               8.824           0.811
# 350          China  2014        5.196               9.386           0.820
# 351          China  2015        5.304               9.449           0.794
# 352          China  2016        5.325               9.510           0.742
# 500          Egypt  2008        4.632               9.186           0.738
# 779           Iraq  2013        4.725               9.280           0.728
# 860         Jordan  2005        6.295               9.246           0.920
# 862         Jordan  2008        4.930               9.343           0.766
# ...

# %%
df[df["Country name"]=="Algeria"]
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 26      Algeria  2011        5.317               9.297           0.810
# 27      Algeria  2012        5.605               9.311           0.839
# 28      Algeria  2014        6.355               9.335           0.818
# 29      Algeria  2016        5.341               9.362           0.749
# 30      Algeria  2017        5.249               9.354           0.807
# 31      Algeria  2018        5.043               9.348           0.799
# 32      Algeria  2019        4.745               9.337           0.803
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 26                             64.66                         0.530
# 27                             64.82                         0.587
# 28                             65.14                           NaN
# 29                             65.50                           NaN
# ...

# %%
df[df["Country name"]=="China"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 342        China  2006        4.560               8.696           0.747
# 343        China  2007        4.863               8.824           0.811
# 344        China  2008        4.846               8.911           0.748
# 345        China  2009        4.454               8.996           0.798
# 346        China  2010        4.653               9.092           0.768
# 347        China  2011        5.037               9.179           0.787
# 348        China  2012        5.095               9.249           0.788
# 349        China  2013        5.241               9.319           0.778
# 350        China  2014        5.196               9.386           0.820
# 351        China  2015        5.304               9.449           0.794
# 352        China  2016        5.325               9.510           0.742
# 353        China  2017        5.099               9.571           0.772
# ...

# %%
df['Freedom to make life choices'] = df['Freedom to make life choices'].fillna(
    df.groupby('Country name')['Freedom to make life choices'].transform('mean')
)

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                    0
# Social support                        0
# Healthy life expectancy at birth      0
# Freedom to make life choices          0
# Generosity                           48
# Perceptions of corruption           101
# Positive affect                       0
# Negative affect                       0
# dtype: int64

# %%
df[df["Generosity"].isnull()]
# Out:
#                  Country name  year  Life Ladder  Log GDP per capita  \
# 28                    Algeria  2014        6.355               9.335
# 29                    Algeria  2016        5.341               9.362
# 66                  Australia  2005        7.341              10.659
# 110                   Bahrain  2012        5.027              10.716
# 111                   Bahrain  2013        6.690              10.757
# 147                   Belgium  2005        7.262              10.745
# 218                    Brazil  2005        6.637               9.438
# 224                    Brazil  2012        6.660               9.647
# 342                     China  2006        4.560               8.696
# 437            Czech Republic  2005        6.439              10.324
# 449                   Denmark  2005        8.019              10.851
# 498                     Egypt  2005        5.168               9.036
# 564                    France  2005        7.093              10.642
# ...

# %%
df[df["Country name"]=="Turkey"]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1753       Turkey  2005        4.719               9.809           0.820
# 1754       Turkey  2007        5.623               9.903           0.792
# 1755       Turkey  2008        5.118               9.899           0.645
# 1756       Turkey  2009        5.213               9.838           0.755
# 1757       Turkey  2010        5.490               9.906           0.795
# 1758       Turkey  2011        5.272               9.996           0.692
# 1759       Turkey  2012        5.309              10.026           0.739
# 1760       Turkey  2013        4.888              10.091           0.795
# 1761       Turkey  2014        5.580              10.124           0.863
# 1762       Turkey  2015        5.514              10.166           0.851
# 1763       Turkey  2016        5.326              10.181           0.880
# 1764       Turkey  2017        5.607              10.238           0.876
# ...

# %%
df[df["Country name"]=="Spain"]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1600        Spain  2005        7.153              10.546           0.961
# 1601        Spain  2007        6.995              10.587           0.957
# 1602        Spain  2008        7.294              10.579           0.948
# 1603        Spain  2009        6.199              10.532           0.929
# 1604        Spain  2010        6.188              10.529           0.950
# 1605        Spain  2011        6.518              10.518           0.944
# 1606        Spain  2012        6.291              10.487           0.937
# 1607        Spain  2013        6.150              10.476           0.929
# 1608        Spain  2014        6.456              10.492           0.948
# 1609        Spain  2015        6.381              10.531           0.956
# 1610        Spain  2016        6.319              10.560           0.942
# 1611        Spain  2017        6.230              10.586           0.903
# ...

# %%
df['Generosity'] = df['Generosity'].fillna(
    df.groupby('Country name')['Generosity'].transform('mean')
)

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                    0
# Social support                        0
# Healthy life expectancy at birth      0
# Freedom to make life choices          0
# Generosity                            0
# Perceptions of corruption           101
# Positive affect                       0
# Negative affect                       0
# dtype: int64

# %%
df[df["Perceptions of corruption"].isnull()]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 28        Algeria  2014        6.355               9.335           0.818
# 29        Algeria  2016        5.341               9.362           0.749
# 113       Bahrain  2015        6.007              10.785           0.853
# 114       Bahrain  2016        6.170              10.781           0.863
# 115       Bahrain  2017        6.227              10.771           0.876
# ...           ...   ...          ...                 ...             ...
# 1902      Vietnam  2014        5.085               8.716           0.792
# 1903      Vietnam  2015        5.076               8.770           0.849
# 1908        Yemen  2007        4.477               8.214           0.825
# 1916        Yemen  2016        3.826               7.715           0.775
# 1917        Yemen  2017        3.254               7.578           0.790
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df[df["Country name"]=="Bahrain"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 107      Bahrain  2009        5.701              10.709           0.904
# 108      Bahrain  2010        5.937              10.706           0.877
# 109      Bahrain  2011        4.824              10.696           0.908
# 110      Bahrain  2012        5.027              10.716           0.911
# 111      Bahrain  2013        6.690              10.757           0.884
# 113      Bahrain  2015        6.007              10.785           0.853
# 114      Bahrain  2016        6.170              10.781           0.863
# 115      Bahrain  2017        6.227              10.771           0.876
# 116      Bahrain  2019        7.098              10.715           0.878
# 117      Bahrain  2020        6.173              10.620           0.848
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 107                             65.94                         0.896
# ...

# %%
df[df["Country name"]=="Yemen"]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1908        Yemen  2007        4.477               8.214           0.825
# 1909        Yemen  2009        4.809               8.278           0.756
# 1910        Yemen  2010        4.350               8.453           0.727
# 1911        Yemen  2011        3.746               8.336           0.663
# 1912        Yemen  2012        4.061               8.236           0.682
# 1913        Yemen  2013        4.218               8.242           0.694
# 1914        Yemen  2014        3.968               8.117           0.638
# 1915        Yemen  2015        2.983               7.858           0.669
# 1916        Yemen  2016        3.826               7.715           0.775
# 1917        Yemen  2017        3.254               7.578           0.790
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1908                              53.4                         0.673
# ...

# %%
df[df["Country name"]=="Vietnam"]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1894      Vietnam  2006        5.294               8.335           0.888
# 1895      Vietnam  2007        5.422               8.394           0.856
# 1896      Vietnam  2008        5.480               8.440           0.805
# 1897      Vietnam  2009        5.304               8.483           0.815
# 1898      Vietnam  2010        5.296               8.535           0.787
# 1899      Vietnam  2011        5.767               8.585           0.898
# 1900      Vietnam  2012        5.535               8.626           0.775
# 1901      Vietnam  2013        5.023               8.668           0.759
# 1902      Vietnam  2014        5.085               8.716           0.792
# 1903      Vietnam  2015        5.076               8.770           0.849
# 1904      Vietnam  2016        5.062               8.820           0.876
# 1906      Vietnam  2018        5.296               8.934           0.832
# ...

# %%
df['Perceptions of corruption'] = df['Perceptions of corruption'].fillna(
    df.groupby('Country name')['Perceptions of corruption'].transform('mean')
)

# %%
df.isnull().sum()
# Out:
# Country name                         0
# year                                 0
# Life Ladder                          0
# Log GDP per capita                   0
# Social support                       0
# Healthy life expectancy at birth     0
# Freedom to make life choices         0
# Generosity                           0
# Perceptions of corruption           25
# Positive affect                      0
# Negative affect                      0
# dtype: int64

# %%
df[df["Perceptions of corruption"].isnull()]
# Out:
#       Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 342          China  2006        4.560               8.696           0.747
# 343          China  2007        4.863               8.824           0.811
# 344          China  2008        4.846               8.911           0.748
# 345          China  2009        4.454               8.996           0.798
# 346          China  2010        4.653               9.092           0.768
# 347          China  2011        5.037               9.179           0.787
# 348          China  2012        5.095               9.249           0.788
# 349          China  2013        5.241               9.319           0.778
# 350          China  2014        5.196               9.386           0.820
# 351          China  2015        5.304               9.449           0.794
# 352          China  2016        5.325               9.510           0.742
# 353          China  2017        5.099               9.571           0.772
# ...

# %%
df[df["Country name"]=="China"]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 342        China  2006        4.560               8.696           0.747
# 343        China  2007        4.863               8.824           0.811
# 344        China  2008        4.846               8.911           0.748
# 345        China  2009        4.454               8.996           0.798
# 346        China  2010        4.653               9.092           0.768
# 347        China  2011        5.037               9.179           0.787
# 348        China  2012        5.095               9.249           0.788
# 349        China  2013        5.241               9.319           0.778
# 350        China  2014        5.196               9.386           0.820
# 351        China  2015        5.304               9.449           0.794
# 352        China  2016        5.325               9.510           0.742
# 353        China  2017        5.099               9.571           0.772
# ...

# %%
df[df["Country name"]=="Turkmenistan"]
# Out:
#       Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1768  Turkmenistan  2009        6.568               8.989           0.924
# 1769  Turkmenistan  2011        5.792               9.182           0.964
# 1770  Turkmenistan  2012        5.464               9.269           0.946
# 1771  Turkmenistan  2013        5.392               9.348           0.846
# 1772  Turkmenistan  2014        5.787               9.427           0.909
# 1773  Turkmenistan  2015        5.791               9.472           0.960
# 1774  Turkmenistan  2016        5.887               9.515           0.929
# 1775  Turkmenistan  2017        5.229               9.561           0.908
# 1776  Turkmenistan  2018        4.621               9.605           0.984
# 1777  Turkmenistan  2019        5.474               9.651           0.982
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1768                             59.44                         0.777
# ...

# %%
df=df.dropna(subset=["Perceptions of corruption"])

# %%
df.isnull().sum()
# Out:
# Country name                        0
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          0
# Perceptions of corruption           0
# Positive affect                     0
# Negative affect                     0
# dtype: int64

# %%
df.to_csv("cleaned_data.csv")
