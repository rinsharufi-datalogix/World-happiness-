# %% [markdown]
# ## DAY 6 :

# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - pandas for data manipulation
#
# - matplotlib and seaborn for visualization

# %% [markdown]
# ## Loading Data

# %%
df=pd.read_csv("cleaned_data.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0 Country name  year  Life Ladder  Log GDP per capita  \
# 0           0  Afghanistan  2008        3.724               7.370
# 1           1  Afghanistan  2009        4.402               7.540
# 2           2  Afghanistan  2010        4.758               7.647
# 3           3  Afghanistan  2011        3.832               7.620
# 4           4  Afghanistan  2012        3.783               7.705
#
#    Social support  Healthy life expectancy at birth  \
# 0           0.451                             50.80
# 1           0.552                             51.20
# 2           0.539                             51.60
# 3           0.521                             51.92
# 4           0.521                             52.24
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.718       0.168                      0.882
# 1                         0.679       0.190                      0.850
# 2                         0.600       0.121                      0.707
# 3                         0.496       0.162                      0.731
# 4                         0.531       0.236                      0.776
#
#    Positive affect  Negative affect
# 0            0.518            0.258
# 1            0.584            0.237
# 2            0.618            0.275
# 3            0.611            0.267
# 4            0.710            0.268

# %% [markdown]
# ## mean :-

# %% [markdown]
# - Average value of all numbers

# %%
df.mean(numeric_only = True)
# Out:
# Unnamed: 0                           967.888709
# year                                2013.168558
# Life Ladder                            5.471796
# Log GDP per capita                     9.356842
# Social support                         0.812686
# Healthy life expectancy at birth      63.361792
# Freedom to make life choices           0.742458
# Generosity                            -0.000956
# Perceptions of corruption              0.743167
# Positive affect                        0.709839
# Negative affect                        0.270131
# dtype: float64

# %% [markdown]
# ## median :-

# %% [markdown]
# - Middle value when numbers are arranged in order

# %%
df.median(numeric_only = True)
# Out:
# Unnamed: 0                           975.000
# year                                2013.000
# Life Ladder                            5.386
# Log GDP per capita                     9.461
# Social support                         0.837
# Healthy life expectancy at birth      65.145
# Freedom to make life choices           0.762
# Generosity                            -0.027
# Perceptions of corruption              0.800
# Positive affect                        0.722
# Negative affect                        0.260
# dtype: float64

# %% [markdown]
# ## mode :-

# %% [markdown]
# - The value that occures most often

# %%
df.mode(numeric_only = True)
# Out:
#       Unnamed: 0    year  Life Ladder  Log GDP per capita  Social support  \
# 0              0  2017.0        5.252              10.546           0.818
# 1              1     NaN          NaN                 NaN           0.937
# 2              2     NaN          NaN                 NaN             NaN
# 3              3     NaN          NaN                 NaN             NaN
# 4              4     NaN          NaN                 NaN             NaN
# ...          ...     ...          ...                 ...             ...
# 1846        1944     NaN          NaN                 NaN             NaN
# 1847        1945     NaN          NaN                 NaN             NaN
# 1848        1946     NaN          NaN                 NaN             NaN
# 1849        1947     NaN          NaN                 NaN             NaN
# 1850        1948     NaN          NaN                 NaN             NaN
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                                 66.4                         0.817
# 1                                 67.2                         0.838
# 2                                 72.2                         0.882
# 3                                 73.0                           NaN
# 4                                  NaN                           NaN
# ...                                ...                           ...
# 1846                               NaN                           NaN
# 1847                               NaN                           NaN
# 1848                               NaN                           NaN
# 1849                               NaN                           NaN
# 1850                               NaN                           NaN
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 0         -0.055                      0.844            0.784            0.206
# 1            NaN                        NaN            0.832              NaN
# 2            NaN                        NaN            0.833              NaN
# 3            NaN                        NaN              NaN              NaN
# 4            NaN                        NaN              NaN              NaN
# ...          ...                        ...              ...              ...
# 1846         NaN                        NaN              NaN              NaN
# 1847         NaN                        NaN              NaN              NaN
# 1848         NaN                        NaN              NaN              NaN
# 1849         NaN                        NaN              NaN              NaN
# 1850         NaN                        NaN              NaN              NaN
#
# [1851 rows x 11 columns]

# %% [markdown]
# ## standard deviation :-

# %%
df.std(numeric_only = True)
# Out:
# Unnamed: 0                          563.059105
# year                                  4.165327
# Life Ladder                           1.129119
# Log GDP per capita                    1.161361
# Social support                        0.119425
# Healthy life expectancy at birth      7.522756
# Freedom to make life choices          0.141941
# Generosity                            0.161462
# Perceptions of corruption             0.188259
# Positive affect                       0.107132
# Negative affect                       0.083358
# dtype: float64

# %% [markdown]
# ## minimum :-

# %% [markdown]
# - lowest value in the dataset

# %%
df.min(numeric_only = True)
# Out:
# Unnamed: 0                             0.000
# year                                2005.000
# Life Ladder                            2.375
# Log GDP per capita                     6.635
# Social support                         0.290
# Healthy life expectancy at birth      32.300
# Freedom to make life choices           0.258
# Generosity                            -0.335
# Perceptions of corruption              0.035
# Positive affect                        0.322
# Negative affect                        0.094
# dtype: float64

# %% [markdown]
# ##  maximum :-

# %% [markdown]
# - Highest value in the dataset

# %%
df.max(numeric_only = True)
# Out:
# Unnamed: 0                          1948.000
# year                                2020.000
# Life Ladder                            8.019
# Log GDP per capita                    11.648
# Social support                         0.987
# Healthy life expectancy at birth      77.100
# Freedom to make life choices           0.985
# Generosity                             0.698
# Perceptions of corruption              0.983
# Positive affect                        0.944
# Negative affect                        0.705
# dtype: float64

# %% [markdown]
# ## describe data :-

# %%
df.describe()
# Out:
#         Unnamed: 0         year  Life Ladder  Log GDP per capita  \
# count  1851.000000  1851.000000  1851.000000         1851.000000
# mean    967.888709  2013.168558     5.471796            9.356842
# std     563.059105     4.165327     1.129119            1.161361
# min       0.000000  2005.000000     2.375000            6.635000
# 25%     483.500000  2010.000000     4.630000            8.440500
# 50%     975.000000  2013.000000     5.386000            9.461000
# 75%    1452.500000  2017.000000     6.311500           10.347000
# max    1948.000000  2020.000000     8.019000           11.648000
#
#        Social support  Healthy life expectancy at birth  \
# count     1851.000000                       1851.000000
# mean         0.812686                         63.361792
# std          0.119425                          7.522756
# min          0.290000                         32.300000
# 25%          0.747500                         58.680000
# 50%          0.837000                         65.145000
# 75%          0.906500                         68.660000
# max          0.987000                         77.100000
#
#        Freedom to make life choices   Generosity  Perceptions of corruption  \
# count                   1851.000000  1851.000000                1851.000000
# mean                       0.742458    -0.000956                   0.743167
# std                        0.141941     0.161462                   0.188259
# min                        0.258000    -0.335000                   0.035000
# 25%                        0.646500    -0.113000                   0.686500
# 50%                        0.762000    -0.027000                   0.800000
# 75%                        0.856000     0.089000                   0.869000
# max                        0.985000     0.698000                   0.983000
#
#        Positive affect  Negative affect
# count      1851.000000      1851.000000
# mean          0.709839         0.270131
# std           0.107132         0.083358
# min           0.322000         0.094000
# 25%           0.626000         0.209000
# 50%           0.722000         0.260000
# 75%           0.799000         0.320500
# max           0.944000         0.705000

# %% [markdown]
# ## quantile :-

# %% [markdown]
# - Dividing data into equal parts

# %%
df.quantile(numeric_only =True)
# Out:
# Unnamed: 0                           975.000
# year                                2013.000
# Life Ladder                            5.386
# Log GDP per capita                     9.461
# Social support                         0.837
# Healthy life expectancy at birth      65.145
# Freedom to make life choices           0.762
# Generosity                            -0.027
# Perceptions of corruption              0.800
# Positive affect                        0.722
# Negative affect                        0.260
# Name: 0.5, dtype: float64

# %% [markdown]
# ## data plots :-

# %%
freq=df["Life Ladder"]
freq.plot(kind='density')
plt.title("Density Plot of Life Ladder")
plt.xlabel("Life Ladder")
plt.show()

# %%
freq=df["Social support"]
freq.plot(kind='density')
plt.title("Density Plot of Social Support")
plt.xlabel("Social Support")
plt.show()

# %%
freq=df["Life Ladder"]
freq.plot(kind='hist')
plt.title("Histogram")
plt.xlabel("Life Ladder")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### INSIGHTS
#
# - Most countries fall in medium happiness range(4-7)
#
# - Very few countries have extremely low or high happiness

# %% [markdown]
# ## plot using sns :-

# %% [markdown]
# ## Distribution of life ladder scores

# %%
sns.histplot(data = df, x = "Life Ladder")
plt.title("Distribution of life ladder score")
plt.xlabel("Life Ladder")
plt.ylabel("count")
plt.show()

# %% [markdown]
# ## Distribution of year

# %%
sns.histplot(data = df, x = "year")
plt.title("Distribution of year")
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter India data
india = df[df['Country name'] == 'India']

# Sort by year (important)
india = india.sort_values('year')

# Plot
plt.figure(figsize=(8,5))
plt.bar(india['year'], india['Life Ladder'], color='skyblue')

plt.title('year-wise Happiness Level in India')
plt.xlabel('year')
plt.ylabel('Happiness Score')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Heat map :-

# %% [markdown]
# ### Correlation Matrix

# %%
plt.figure(figsize=(10,6))
corr =df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.title("correlation Matrix")
plt.show()

# %% [markdown]
# ### INSIGHTS
#
# - Happiness has a strong relationship with GDP
#
# - Social support also strongly affects happiness

# %%
df.corr(numeric_only=True)
# Out:
#                                   Unnamed: 0      year  Life Ladder  \
# Unnamed: 0                          1.000000 -0.015328    -0.006545
# year                               -0.015328  1.000000     0.040500
# Life Ladder                        -0.006545  0.040500     1.000000
# Log GDP per capita                 -0.003225  0.079009     0.795206
# Social support                      0.133983 -0.009844     0.712856
# Healthy life expectancy at birth   -0.015208  0.168822     0.751722
# Freedom to make life choices        0.043393  0.227083     0.526091
# Generosity                          0.081014 -0.039606     0.188043
# Perceptions of corruption          -0.047429 -0.093965    -0.457399
# Positive affect                     0.058269  0.008328     0.539547
# Negative affect                    -0.143365  0.193609    -0.300695
#
#                                   Log GDP per capita  Social support  \
# Unnamed: 0                                 -0.003225        0.133983
# year                                        0.079009       -0.009844
# Life Ladder                                 0.795206        0.712856
# Log GDP per capita                          1.000000        0.697106
# Social support                              0.697106        1.000000
# Healthy life expectancy at birth            0.851255        0.618862
# Freedom to make life choices                0.359297        0.416688
# Generosity                                 -0.010099        0.063099
# Perceptions of corruption                  -0.364515       -0.235377
# Positive affect                             0.306583        0.450428
# Negative affect                            -0.214852       -0.405586
#
#                                   Healthy life expectancy at birth  \
# Unnamed: 0                                               -0.015208
# year                                                      0.168822
# Life Ladder                                               0.751722
# Log GDP per capita                                        0.851255
# Social support                                            0.618862
# Healthy life expectancy at birth                          1.000000
# Freedom to make life choices                              0.387617
# Generosity                                                0.026422
# Perceptions of corruption                                -0.335025
# Positive affect                                           0.320313
# Negative affect                                          -0.140831
#
#                                   Freedom to make life choices  Generosity  \
# Unnamed: 0                                            0.043393    0.081014
# year                                                  0.227083   -0.039606
# Life Ladder                                           0.526091    0.188043
# Log GDP per capita                                    0.359297   -0.010099
# Social support                                        0.416688    0.063099
# Healthy life expectancy at birth                      0.387617    0.026422
# Freedom to make life choices                          1.000000    0.335067
# Generosity                                            0.335067    1.000000
# Perceptions of corruption                            -0.491218   -0.286331
# Positive affect                                       0.612265    0.377448
# Negative affect                                      -0.260973   -0.093698
#
#                                   Perceptions of corruption  Positive affect  \
# Unnamed: 0                                        -0.047429         0.058269
# year                                              -0.093965         0.008328
# Life Ladder                                       -0.457399         0.539547
# Log GDP per capita                                -0.364515         0.306583
# Social support                                    -0.235377         0.450428
# Healthy life expectancy at birth                  -0.335025         0.320313
# Freedom to make life choices                      -0.491218         0.612265
# Generosity                                        -0.286331         0.377448
# Perceptions of corruption                          1.000000        -0.305260
# Positive affect                                   -0.305260         1.000000
# Negative affect                                    0.256872        -0.369703
#
#                                   Negative affect
# Unnamed: 0                              -0.143365
# year                                     0.193609
# Life Ladder                             -0.300695
# Log GDP per capita                      -0.214852
# Social support                          -0.405586
# Healthy life expectancy at birth        -0.140831
# Freedom to make life choices            -0.260973
# Generosity                              -0.093698
# Perceptions of corruption                0.256872
# Positive affect                         -0.369703
# Negative affect                          1.000000

# %%
corr=df.corr(numeric_only=True)
print(corr)
# Out:
#                                   Unnamed: 0      year  Life Ladder  \
# Unnamed: 0                          1.000000 -0.015328    -0.006545
# year                               -0.015328  1.000000     0.040500
# Life Ladder                        -0.006545  0.040500     1.000000
# Log GDP per capita                 -0.003225  0.079009     0.795206
# Social support                      0.133983 -0.009844     0.712856
# Healthy life expectancy at birth   -0.015208  0.168822     0.751722
# Freedom to make life choices        0.043393  0.227083     0.526091
# Generosity                          0.081014 -0.039606     0.188043
# Perceptions of corruption          -0.047429 -0.093965    -0.457399
# Positive affect                     0.058269  0.008328     0.539547
# Negative affect                    -0.143365  0.193609    -0.300695
#
#                                   Log GDP per capita  Social support  \
# Unnamed: 0                                 -0.003225        0.133983
# year                                        0.079009       -0.009844
# Life Ladder                                 0.795206        0.712856
# Log GDP per capita                          1.000000        0.697106
# Social support                              0.697106        1.000000
# Healthy life expectancy at birth            0.851255        0.618862
# Freedom to make life choices                0.359297        0.416688
# Generosity                                 -0.010099        0.063099
# Perceptions of corruption                  -0.364515       -0.235377
# Positive affect                             0.306583        0.450428
# Negative affect                            -0.214852       -0.405586
#
#                                   Healthy life expectancy at birth  \
# Unnamed: 0                                               -0.015208
# year                                                      0.168822
# Life Ladder                                               0.751722
# Log GDP per capita                                        0.851255
# Social support                                            0.618862
# Healthy life expectancy at birth                          1.000000
# Freedom to make life choices                              0.387617
# Generosity                                                0.026422
# Perceptions of corruption                                -0.335025
# Positive affect                                           0.320313
# Negative affect                                          -0.140831
#
#                                   Freedom to make life choices  Generosity  \
# Unnamed: 0                                            0.043393    0.081014
# year                                                  0.227083   -0.039606
# Life Ladder                                           0.526091    0.188043
# Log GDP per capita                                    0.359297   -0.010099
# Social support                                        0.416688    0.063099
# Healthy life expectancy at birth                      0.387617    0.026422
# Freedom to make life choices                          1.000000    0.335067
# Generosity                                            0.335067    1.000000
# Perceptions of corruption                            -0.491218   -0.286331
# Positive affect                                       0.612265    0.377448
# Negative affect                                      -0.260973   -0.093698
#
#                                   Perceptions of corruption  Positive affect  \
# Unnamed: 0                                        -0.047429         0.058269
# year                                              -0.093965         0.008328
# Life Ladder                                       -0.457399         0.539547
# Log GDP per capita                                -0.364515         0.306583
# Social support                                    -0.235377         0.450428
# Healthy life expectancy at birth                  -0.335025         0.320313
# Freedom to make life choices                      -0.491218         0.612265
# Generosity                                        -0.286331         0.377448
# Perceptions of corruption                          1.000000        -0.305260
# Positive affect                                   -0.305260         1.000000
# Negative affect                                    0.256872        -0.369703
#
#                                   Negative affect
# Unnamed: 0                              -0.143365
# year                                     0.193609
# Life Ladder                             -0.300695
# Log GDP per capita                      -0.214852
# Social support                          -0.405586
# Healthy life expectancy at birth        -0.140831
# Freedom to make life choices            -0.260973
# Generosity                              -0.093698
# Perceptions of corruption                0.256872
# Positive affect                         -0.369703
# Negative affect                          1.000000

# %% [markdown]
# ## GDP vs Happiness

# %%
plt.figure()
sns.scatterplot(x='Log GDP per capita',y='Life Ladder',data=df)
plt.title("GDP vs Happiness")
plt.xlabel("Log GDP per capita")
plt.ylabel("Life Ladder")
plt.show()

# %% [markdown]
# ### INSIGHT :-

# %% [markdown]
# - As Log GDP per capita increases , the LIfe Ladder (Happiness score) also increases

# %% [markdown]
# ## Social support vs Happiness

# %%
plt.figure()
plt.scatter(df["Social support"],df["Life Ladder"])
plt.title("Social support vs happiness")
plt.xlabel("Social support")
plt.ylabel("Life Ladder")
plt.show()

# %% [markdown]
# ### INSIGHT:-
#
# - As Social Support increases , Life Ladder (Happiness) also increases

# %% [markdown]
# ## Positive affect vs Negative affect

# %%
plt.scatter(df["Positive affect"],df["Negative affect"])
plt.title("Positive affect vs Negative affect")
plt.xlabel("Positive affect")
plt.ylabel("Negative affect")
plt.show()

# %% [markdown]
# ### INSIGHT :-
#
# - As positive affect increases , negative affect slightly decreases
#
# - there is a weak negative relationship between positive  and negative affect

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(df[["Life Ladder","Log GDP per capita","Social support","Healthy life expectancy at birth","Freedom to make life choices"]])
plt.show()

# %% [markdown]
# ### INSIGHT
#
# - Happiness increases with GDP,social support , and health, showing a strong positive relationship between these factors
#
# - As negative affect increases , happiness (Life Ladder)decreases

# %% [markdown]
# ## HIstogram of Life Ladder :-

# %%
plt.figure()
plt.hist(df['Life Ladder'], bins=20, edgecolor="black")
plt.title("Distribution of Happiness")
plt.xlabel("Life Ladder")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### INSIGHTS :-
#
# Most countries fall in medium happiness range(4-7)
#
# Very few countries have extremely low or high happiness

# %% [markdown]
# ## Distribution of GDP

# %%
plt.figure(figsize=(7,5))
plt.hist(df['Log GDP per capita'], bins=20, edgecolor='black')
plt.title('Distribution of GDP')
plt.xlabel('GDP per capita')
plt.ylabel('Number of countries')
plt.show()

# %% [markdown]
# ### INSIGHT
#
# - this histogram shows how GDP values are distributed
#
# - most countries are in the middle income range few countries have very high GDP

# %% [markdown]
# ## Country vs Happiness(Before 2006)

# %%
import matplotlib.pyplot as plt

# Filter data before 2006
data_2005 = df[df["year"] < 2006]

# Take average happiness per country
avg_data = data_2005.groupby("Country name")["Life Ladder"].mean()

# Plot
plt.figure(figsize=(10,6))
avg_data.plot(kind="bar", color="skyblue")

plt.title("Country vs Happiness (Before 2006)")
plt.xlabel("Country")
plt.ylabel("Life Ladder")

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## INSIGHTS
#
# - this chart shows the happiness level of india for each year
#
# - we can see how hapiness changes year by year
#
# - some years show increase , while some show decrease

# %% [markdown]
# ## Histogram of Life Ladder

# %%
data_2006 = df[df["year"] == 2006]

plt.figure()
plt.hist(data_2006["Life Ladder"], bins=20)

plt.title("Histogram of Life Ladder")
plt.xlabel("Life Ladder")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ## INSIGHTS
#
# - This histogram shows how happiness scores are distributed in the year 2006.
#
#
# - Most countries fall in the middle happiness range.
#
#
# - Few countries have very low or very high happiness.

# %%
data_2005 = df[df["year"] < 2006]

plt.figure()
plt.hist(data_2005["Life Ladder"], bins=20)

plt.title("Histogram of Life Ladder")
plt.xlabel("Life Ladder")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ## AVERAGE HAPPINESS OVER YEARS

# %%
year_avg=df.groupby("year")["Life Ladder"].mean()
plt.figure()
plt.plot(year_avg.index,year_avg.values)
plt.title("Average happiness over years")
plt.xlabel("year")
plt.ylabel("Life Ladder")
plt.show()

# %% [markdown]
# ### INSIGHT :-
#
# Shows overall global trend
#
# Helps identity increase/decrease in happiness over years

# %% [markdown]
# ## TOP 10 HAPPIEST COUNTRIES

# %%
top10=df.groupby("Country name")["Life Ladder"].mean().sort_values(ascending=False).head(10)
plt.figure()
top10.plot(kind="bar")
plt.title("Top 10 happist countries")
plt.xlabel("Country")
plt.ylabel("Life Ladder")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Easy comparison between countries
#
# Highlights best performing nations

# %% [markdown]
# This bar chart shows how average happiness changes over different years.
#
# It helps us understand trends over time.

# %% [markdown]
# ## Positive affect distribution

# %%
plt.figure()
plt.hist(df["Positive affect"],bins=10)
plt.title("Positive affect distribution")
plt.xlabel("Positive affect")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### INSIGHT :-
#
# Most countries show moderate to High positive emotions

# %% [markdown]
# ## Happiness trend of india

# %%
country="India"
data=df[df["Country name"]==country]
plt.figure()
plt.plot(data["year"],data["Life Ladder"])
plt.title(f"Happiness Trend in {country}")
plt.xlabel("year")
plt.ylabel("Life Ladder")
plt.show()

# %% [markdown]
# ## INSIGHTS
#
# Shows country progress
#
# Useful for case study.

# %% [markdown]
# ## Happiness trend of Afghanistan

# %%
country="Afghanistan"
data=df[df["Country name"]==country]
plt.figure()
plt.plot(data["year"],data["Life Ladder"])
plt.title(f"Happiness Trend in {country}")
plt.xlabel("year")
plt.ylabel("Life Ladder")
plt.show()

# %% [markdown]
# ## INSIGHTS
#
# Shows country progress
#
# Useful for case study.

# %% [markdown]
# ## Healthy life expectancy trend

# %%
life_avg = df.groupby("year")["Healthy life expectancy at birth"].mean()
plt.figure(figsize=(7,5))
plt.plot(life_avg.index, life_avg.values, marker='o')
plt.title('Healthy Life Expectancy Trend')
plt.xlabel('year')
plt.ylabel('Life Expectancy')
plt.grid()
plt.show()

# %% [markdown]
# ## INSIGHTS
#
# Shows country progress
#
# Useful for case study

# %% [markdown]
# ## Happiness trend over years

# %%
year_avg = df.groupby('year')['Life Ladder'].mean()
plt.figure(figsize=(7,5))
plt.plot(year_avg.index,year_avg.values,marker='o')
plt.title('Happiness Trend Over Years')
plt.xlabel('year')
plt.ylabel('Happiness Score')
plt.grid()
plt.show()

# %% [markdown]
# ## INSIGHT
#
# - This line graph shows happiness changes over time
#
# - We can see the trend of happiness across diffrent years
#
# - It helps us understand whether happiness is increasing or decreasing

# %% [markdown]
# ## Economic Comparison of First 10 countries

# %%
top10=df.groupby("Country name")["Life Ladder"].mean().sort_values(ascending=False).head(10)
plt.figure()
top10.plot(kind="bar")
plt.title("Top 10 happist countries")
plt.xlabel("Country")
plt.ylabel("Life Ladder")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## INSIGHT
#
# - The graph shows differencesin economic levels among the first 10 countries
#
# - Countries with higher Log GDP per capita indicate stronger economies

# %% [markdown]
# # yearly change in happiness

# %%
year_avg=df.groupby("year")["Life Ladder"].mean()
change=year_avg.diff()
plt.figure()
plt.plot(change.index,change.values)
plt.title("yearly change in happiness")
plt.xlabel("year")
plt.ylabel("change in Life Ladder")
plt.axhline(0)
plt.show()

# %%
# Filter India data
india = df[df['Country name']== 'India']
#sort by year(important)
india = india.sort_values('year')
# plot
plt.figure(figsize=(8,5))
plt.bar(india['year'],india['Life Ladder'],color='skyblue')
plt.title('year_wise Happiness Level in India')
plt.xlabel('year')
plt.ylabel('happiness Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## INSIGHTS
#
# This chart shows the happiness level of India for each year
#
# We can see how happiness year by year
#
# Some years show increase, while some show decrease

# %%
countries = ['India', 'Finland', 'United States', 'Brazil']

data = df[df['Country name'].isin(countries)]

avg_data = data.groupby('Country name')['Life Ladder'].mean()

plt.figure(figsize=(7,5))
avg_data.plot(kind='bar', color=['blue','green','orange','red'])

plt.title('Average Happiness Comparison')
plt.xlabel('Country')
plt.ylabel('Life Ladder (Happiness Score)')
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# ## INSIGHT
#
# - This chart compares happiness score between different countries
#
# - Finland has higher happiness, while India has moderate levels
#
# - This shows differences in economic and social conditions

# %%
df
# Out:
#       Unnamed: 0 Country name  year  Life Ladder  Log GDP per capita  \
# 0              0  Afghanistan  2008        3.724               7.370
# 1              1  Afghanistan  2009        4.402               7.540
# 2              2  Afghanistan  2010        4.758               7.647
# 3              3  Afghanistan  2011        3.832               7.620
# 4              4  Afghanistan  2012        3.783               7.705
# ...          ...          ...   ...          ...                 ...
# 1846        1944     Zimbabwe  2016        3.735               7.984
# 1847        1945     Zimbabwe  2017        3.638               8.016
# 1848        1946     Zimbabwe  2018        3.616               8.049
# 1849        1947     Zimbabwe  2019        2.694               7.950
# 1850        1948     Zimbabwe  2020        3.160               7.829
#
#       Social support  Healthy life expectancy at birth  \
# 0              0.451                             50.80
# 1              0.552                             51.20
# 2              0.539                             51.60
# 3              0.521                             51.92
# 4              0.521                             52.24
# ...              ...                               ...
# 1846           0.768                             54.40
# 1847           0.754                             55.00
# 1848           0.775                             55.60
# 1849           0.759                             56.20
# 1850           0.717                             56.80
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                            0.718       0.168                      0.882
# 1                            0.679       0.190                      0.850
# 2                            0.600       0.121                      0.707
# 3                            0.496       0.162                      0.731
# 4                            0.531       0.236                      0.776
# ...                            ...         ...                        ...
# 1846                         0.733      -0.095                      0.724
# 1847                         0.753      -0.098                      0.751
# 1848                         0.763      -0.068                      0.844
# 1849                         0.632      -0.064                      0.831
# 1850                         0.643      -0.009                      0.789
#
#       Positive affect  Negative affect
# 0               0.518            0.258
# 1               0.584            0.237
# 2               0.618            0.275
# 3               0.611            0.267
# 4               0.710            0.268
# ...               ...              ...
# 1846            0.738            0.209
# 1847            0.806            0.224
# 1848            0.710            0.212
# 1849            0.716            0.235
# 1850            0.703            0.346
#
# [1851 rows x 12 columns]
